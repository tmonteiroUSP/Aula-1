# %% [markdown]
# <a href="https://colab.research.google.com/github/tmonteiroUSP/Aula-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bioestatística
#
# ##nome sobrenome Num USP
# ###Raianne Brandão
# ###Tiago Monteiro 16991607
# ###Vitória Ortiz
#
#
# # Tipos de variáveis
#
# ## discreta
#
# ## continua
#
# ## ordinal
#
# ## nominal

# %%
import pandas as pd

df = pd.read_excel('dados.xlsx')

# %%
df
# Out:
#     Quantos dias por semana você estuda Biologia?  \
# 0                                               5
# 1                                               6
# 2                                               5
# 3                                               5
# 4                                               5
# 5                                               3
# 6                                               5
# 7                                               5
# 8                                               7
# 9                                               5
# 10                                              6
# 11                                              6
# 12                                              5
# 13                                              5
# 14                                              6
# 15                                              6
# 16                                              6
# 17                                              2
# ...

# %%
df.head(2)
# Out:
#    Quantos dias por semana você estuda Biologia?  \
# 0                                              5
# 1                                              6
#
#    Quantas horas você dedica aos estudos de Biologia em uma semana?  \
# 0                                                 10
# 1                                                 10
#
#    Quantas espécies de plantas você consegue identificar corretamente em uma atividade prática?  \
# 0                                                  3
# 1                                                  3
#
#   Qual o tamanho da folha analisada, em milímetros?  \
# 0                                                60
# 1                                               120
#
#   Qual o nível de dificuldade da atividade prática?  \
# 0                                          moderado
# 1                                           difícil
#
#   Qual o estágio de desenvolvimento do organismo observado?  \
# ...

# %%
df.tail(2)
# Out:
#     Quantos dias por semana você estuda Biologia?  \
# 21                                              6
# 22                                              5
#
#     Quantas horas você dedica aos estudos de Biologia em uma semana?  \
# 21                                                 15
# 22                                                 12
#
#     Quantas espécies de plantas você consegue identificar corretamente em uma atividade prática?  \
# 21                                                 23
# 22                                                  8
#
#    Qual o tamanho da folha analisada, em milímetros?  \
# 21                                                50
# 22                                                25
#
#    Qual o nível de dificuldade da atividade prática?  \
# 21                                             fácil
# 22                                          moderado
#
#    Qual o estágio de desenvolvimento do organismo observado?  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Quantos dias por semana você estuda Biologia?                                                 23 non-null     int64
#  1   Quantas horas você dedica aos estudos de Biologia em uma semana?                              23 non-null     int64
#  2   Quantas espécies de plantas você consegue identificar corretamente em uma atividade prática?  23 non-null     int64
#  3   Qual o tamanho da folha analisada, em milímetros?                                             23 non-null     object
#  4   Qual o nível de dificuldade da atividade prática?                                             23 non-null     object
# ...
